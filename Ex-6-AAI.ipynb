# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
#importing packages
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#reading content from file
f = open("/content/sample.txt", "r")
sentences = f.readlines()
f.close()

# %%
verbs = [[] for _ in sentences]
i=0
for sentence in sentences:
  print("Sentence",i+1,":", sentence)

  # Tokenize the sentence into words
  words = word_tokenize(sentence)

  # Identify the parts of speech for each word
  pos_tags = nltk.pos_tag(words)

  # Print the parts of speech
  for word,tag in pos_tags:
    print(word,"->",tag)

    # Save verbs
    if tag.startswith('VB'):
      verbs[i].append(word)
  i+=1
  print("\n\n")
# Out:
# Sentence 1 : The sun set behind the horizon, painting the sky in shades of orange and pink.
#
# The -> DT
# sun -> NN
# set -> VBN
# behind -> IN
# the -> DT
# horizon -> NN
# , -> ,
# painting -> VBG
# the -> DT
# sky -> NN
# in -> IN
# shades -> NNS
# of -> IN
# orange -> NN
# and -> CC
# pink -> NN
# . -> .
#
#
#
# Sentence 2 : Lucas plays the guitar in a local band every Friday night.
#
# Lucas -> NNP
# plays -> VBZ
# the -> DT
# guitar -> NN
# in -> IN
# a -> DT
# local -> JJ
# band -> NN
# every -> DT
# Friday -> NNP
# night -> NN
# . -> .
#
#
#
# Sentence 3 : Gardening is a therapeutic activity that many people enjoy.
#
# Gardening -> NNP
# is -> VBZ
# a -> DT
# therapeutic -> JJ
# activity -> NN
# that -> IN
# many -> JJ
# people -> NNS
# enjoy -> VBP
# . -> .
#
#
#
# Sentence 4 : The ancient ruins tell stories of civilizations long gone.
#
# The -> DT
# ancient -> JJ
# ruins -> NNS
# tell -> VBP
# stories -> NNS
# of -> IN
# civilizations -> NNS
# long -> JJ
# gone -> VBN
# . -> .
#
#
#
# Sentence 5 : Catherine dreams of traveling the world and experiencing different cultures.
#
# Catherine -> NNP
# dreams -> NN
# of -> IN
# traveling -> VBG
# the -> DT
# world -> NN
# and -> CC
# experiencing -> VBG
# different -> JJ
# cultures -> NNS
# . -> .
#
#
#
# Sentence 6 : Innovation drives progress in science and technology.
#
# Innovation -> NN
# drives -> NNS
# progress -> NN
# in -> IN
# science -> NN
# and -> CC
# technology -> NN
# . -> .
#
#
#
# Sentence 7 : The laughter of children echoed through the playground.
#
# The -> DT
# laughter -> NN
# of -> IN
# children -> NNS
# echoed -> VBN
# through -> IN
# the -> DT
# playground -> NN
# . -> .
#
#
#
# Sentence 8 : Reading books opens up a world of imagination and knowledge.
#
# Reading -> VBG
# books -> NNS
# opens -> VBZ
# up -> RP
# a -> DT
# world -> NN
# of -> IN
# imagination -> NN
# and -> CC
# knowledge -> NN
# . -> .
#
#
#
# Sentence 9 : Dancing is a form of expression that brings joy to many.
#
# Dancing -> NNP
# is -> VBZ
# a -> DT
# form -> NN
# of -> IN
# expression -> NN
# that -> WDT
# brings -> VBZ
# joy -> NN
# to -> TO
# many -> JJ
# . -> .
#
#
#
# Sentence 10 : Wildlife conservation efforts are vital to protect endangered species.
#
# Wildlife -> NNP
# conservation -> NN
# efforts -> NNS
# are -> VBP
# vital -> JJ
# to -> TO
# protect -> VB
# endangered -> JJ
# species -> NNS
# . -> .
#
#
#
# Sentence 11 : The sound of waves crashing on the shore is soothing to the soul.
#
# The -> DT
# sound -> NN
# of -> IN
# waves -> NNS
# crashing -> VBG
# on -> IN
# the -> DT
# shore -> NN
# is -> VBZ
# soothing -> VBG
# to -> TO
# the -> DT
# soul -> NN
# . -> .
#
#
#
# Sentence 12 : Exploring new cuisines can be a delightful culinary adventure.
#
# Exploring -> VBG
# new -> JJ
# cuisines -> NNS
# can -> MD
# be -> VB
# a -> DT
# delightful -> JJ
# culinary -> JJ
# adventure -> NN
# . -> .
#
#
#
# Sentence 13 : Meditation helps to calm the mind and reduce stress.
#
# Meditation -> NN
# helps -> VBZ
# to -> TO
# calm -> VB
# the -> DT
# mind -> NN
# and -> CC
# reduce -> VB
# stress -> NN
# . -> .
#
#
#
# Sentence 14 : Learning from past mistakes is crucial for personal growth.
#
# Learning -> VBG
# from -> IN
# past -> JJ
# mistakes -> NNS
# is -> VBZ
# crucial -> JJ
# for -> IN
# personal -> JJ
# growth -> NN
# . -> .
#
#
#
# Sentence 15 : The vibrant colors of the autumn leaves create a stunning display.
#
# The -> DT
# vibrant -> JJ
# colors -> NNS
# of -> IN
# the -> DT
# autumn -> NN
# leaves -> VBZ
# create -> VBP
# a -> DT
# stunning -> JJ
# display -> NN
# . -> .
#
#
#
# Sentence 16 : Music festivals bring people together to celebrate and enjoy live music.
#
# Music -> JJ
# festivals -> NNS
# bring -> VBP
# people -> NNS
# together -> RB
# to -> TO
# celebrate -> VB
# and -> CC
# enjoy -> VB
# live -> JJ
# music -> NN
# . -> .
#
#
#
# Sentence 17 : Artists express themselves through various forms of creative expression.
#
# Artists -> NNS
# express -> VBP
# themselves -> PRP
# through -> IN
# various -> JJ
# forms -> NNS
# of -> IN
# creative -> JJ
# expression -> NN
# . -> .
#
#
#
# Sentence 18 : Cycling is an eco-friendly mode of transportation that promotes fitness.
#
# Cycling -> NN
# is -> VBZ
# an -> DT
# eco-friendly -> JJ
# mode -> NN
# of -> IN
# transportation -> NN
# that -> IN
# promotes -> VBZ
# fitness -> NN
# . -> .
#
#
#
# Sentence 19 : The majestic architecture of the cathedral attracts tourists from all over the world.
#
# The -> DT
# majestic -> JJ
# architecture -> NN
# of -> IN
# the -> DT
# cathedral -> JJ
# attracts -> NNS
# tourists -> NNS
# from -> IN
# all -> DT
# over -> IN
# the -> DT
# world -> NN
# . -> .
#
#
#
# Sentence 20 : Cooking homemade meals allows for customization and healthier options.
#
# Cooking -> VBG
# homemade -> NN
# meals -> NNS
# allows -> VBZ
# for -> IN
# customization -> NN
# and -> CC
# healthier -> NN
# options -> NNS
# . -> .
#
#
#
# Sentence 21 : Sustainable farming practices help to preserve the environment.
#
# Sustainable -> JJ
# farming -> NN
# practices -> NNS
# help -> VBP
# to -> TO
# preserve -> VB
# the -> DT
# environment -> NN
# . -> .
#
#
#
# Sentence 22 : Photography captures moments that last a lifetime.
#
# Photography -> NNP
# captures -> VBZ
# moments -> NNS
# that -> IN
# last -> JJ
# a -> DT
# lifetime -> NN
# . -> .
#
#
#
# Sentence 23 : Hiking in the mountains offers breathtaking views and a sense of accomplishment.
#
# Hiking -> VBG
# in -> IN
# the -> DT
# mountains -> NNS
# offers -> NNS
# breathtaking -> VBG
# views -> NNS
# and -> CC
# a -> DT
# sense -> NN
# of -> IN
# accomplishment -> NN
# . -> .
#
#
#
# Sentence 24 : Social media platforms connect people from different parts of the world.
#
# Social -> JJ
# media -> NNS
# platforms -> NNS
# connect -> VBP
# people -> NNS
# from -> IN
# different -> JJ
# parts -> NNS
# of -> IN
# the -> DT
# world -> NN
# . -> .
#
#
#
# Sentence 25 : Attending live theater performances is a cultural experience worth cherishing.
#
# Attending -> VBG
# live -> JJ
# theater -> NN
# performances -> NNS
# is -> VBZ
# a -> DT
# cultural -> JJ
# experience -> NN
# worth -> JJ
# cherishing -> NN
# . -> .
#
#
#
# Sentence 26 : The beauty of nature inspires artists and poets alike.
#
# The -> DT
# beauty -> NN
# of -> IN
# nature -> NN
# inspires -> NNS
# artists -> NNS
# and -> CC
# poets -> NNS
# alike -> RB
# . -> .
#
#
#
# Sentence 27 : Journaling is a reflective practice that can enhance self-awareness.
#
# Journaling -> NNP
# is -> VBZ
# a -> DT
# reflective -> JJ
# practice -> NN
# that -> WDT
# can -> MD
# enhance -> VB
# self-awareness -> JJ
# . -> .
#
#
#
# Sentence 28 : Adventure travel provides thrilling experiences and unforgettable memories.
#
# Adventure -> NNP
# travel -> NN
# provides -> VBZ
# thrilling -> JJ
# experiences -> NNS
# and -> CC
# unforgettable -> JJ
# memories -> NNS
# . -> .
#
#
#
# Sentence 29 : Inclusivity and diversity enrich communities and foster understanding.
#
# Inclusivity -> NN
# and -> CC
# diversity -> NN
# enrich -> JJ
# communities -> NNS
# and -> CC
# foster -> JJ
# understanding -> NN
# . -> .
#
#
#
# Sentence 30 : The importance of family bonds cannot be overstated.
#
# The -> DT
# importance -> NN
# of -> IN
# family -> NN
# bonds -> NNS
# can -> MD
# not -> RB
# be -> VB
# overstated -> VBN
# . -> .
#
#
#
# Sentence 31 : Learning new skills keeps the mind sharp and opens doors to opportunities.
#
# Learning -> VBG
# new -> JJ
# skills -> NNS
# keeps -> VBZ
# the -> DT
# mind -> NN
# sharp -> JJ
# and -> CC
# opens -> VBZ
# doors -> NNS
# to -> TO
# opportunities -> NNS
# . -> .
#
#
#
# Sentence 32 : Entrepreneurship drives economic growth and innovation.
#
# Entrepreneurship -> NNP
# drives -> VBZ
# economic -> JJ
# growth -> NN
# and -> CC
# innovation -> NN
# . -> .

# %%
print("Synonyms and Antonymns for verbs in each sentence:\n")
i=0
for sentence in sentences:
  print("Sentence",i+1,":", sentence)
  pos_tags = nltk.pos_tag(verbs[i])
  for word,tag in pos_tags:
    print(word,"->",tag)
    synonyms = []
    antonyms = []
    for syn in wordnet.synsets(word):
      for lemma in syn.lemmas():
        synonyms.append(lemma.name())
        if lemma.antonyms():
          for antonym in lemma.antonyms():
            antonyms.append(antonym.name())

    # Print the synonyms and antonyms
    print("Synonyms:",set(synonyms))
    print("Antonyms:", set(antonyms) if antonyms else "None")
    print()
  print("\n\n")
  i+=1
# Out:
# Synonyms and Antonymns for verbs in each sentence:
#
# Sentence 1 : The sun set behind the horizon, painting the sky in shades of orange and pink.
#
# set -> VBN
# Synonyms: {'correct', 'bent', 'arrange', 'Seth', 'put', 'fix', 'dress', 'mark', 'hardening', 'set', 'coiffure', 'lot', 'fixed', 'rigid', 'typeset', 'do', 'set_up', 'exercise_set', 'sic', 'ready', 'lay_out', 'congeal', 'primed', 'placed', 'plant', 'situated', 'gear_up', 'located', 'fit', 'rig', 'determined', 'solidifying', 'hardened', 'pose', 'readiness', 'specify', 'localise', 'lay', 'adjust', 'countersink', 'laid', 'coif', 'circle', 'Set', 'determine', 'localize', 'limit', 'go_down', 'band', 'curing', 'place', 'go_under', 'fructify', 'define', 'jell', 'dictated', 'coiffe', 'prepare', 'solidification', 'stage_set', 'position'}
# Antonyms: {'rise'}
#
# painting -> NN
# Synonyms: {'paint', 'picture', 'house_painting', 'painting'}
# Antonyms: None
#
#
#
#
# Sentence 2 : Lucas plays the guitar in a local band every Friday night.
#
# plays -> NNS
# Synonyms: {'take_on', 'dally', 'run', 'bet', 'manoeuvre', 'fiddle', 'gambling', 'work', 'encounter', 'recreate', 'represent', 'drama', 'romp', 'shimmer', 'flirt', 'bid', 'caper', 'act_as', 'make_for', 'playing_period', 'toy', 'free_rein', 'wager', 'gaming', 'gambol', 'playact', 'looseness', 'bring', 'meet', 'play', 'swordplay', "child's_play", 'roleplay', 'trifle', 'period_of_play', 'dramatic_play', 'sport', 'wreak', 'act', 'diddle', 'maneuver', 'turn', 'fun', 'frolic', 'spiel'}
# Antonyms: {'tightness'}
#
#
#
#
# Sentence 3 : Gardening is a therapeutic activity that many people enjoy.
#
# is -> VBZ
# Synonyms: {'represent', 'be', 'exist', 'follow', 'cost', 'comprise', 'embody', 'personify', 'constitute', 'make_up', 'equal', 'live'}
# Antonyms: {'differ'}
#
# enjoy -> NN
# Synonyms: {'enjoy', 'bask', 'savour', 'relish', 'delight', 'love', 'savor', 'revel'}
# Antonyms: {'suffer'}
#
#
#
#
# Sentence 4 : The ancient ruins tell stories of civilizations long gone.
#
# tell -> VB
# Synonyms: {'tell_apart', 'severalise', 'say', 'order', 'assure', 'Tell', 'William_Tell', 'secern', 'narrate', 'severalize', 'enjoin', 'secernate', 'tell', 'recount', 'differentiate', 'separate', 'state', 'recite', 'evidence', 'distinguish'}
# Antonyms: None
#
# gone -> VBN
# Synonyms: {'fail', 'locomote', 'run', 'last', 'endure', 'decease', 'proceed', 'exit', 'buy_the_farm', 'bypast', 'survive', 'work', 'lead', 'kick_the_bucket', 'get', 'run_low', 'rifle', 'give_out', 'kaput', 'gone', 'at_peace', 'foregone', 'live', 'operate', 'choke', 'perish', 'go_away', 'function', 'at_rest', 'give_way', 'live_on', 'deceased', 'break_down', 'run_short', 'fit', 'croak', 'extend', 'expire', 'pass_away', 'pop_off', 'conk_out', 'move', 'belong', 'plump', 'pass', 'depart', 'hold_out', 'break', 'conk', 'go', 'asleep', 'start', 'become', "cash_in_one's_chips", 'blend', 'go_bad', 'bygone', 'give-up_the_ghost', 'hold_up', 'drop_dead', 'travel', 'die', 'get_going', 'snuff_it', 'blend_in', 'departed', 'done_for', 'sound'}
# Antonyms: {'stay_in_place', 'come', 'malfunction', 'stop', 'be_born'}
#
#
#
#
# Sentence 5 : Catherine dreams of traveling the world and experiencing different cultures.
#
# traveling -> VBG
# Synonyms: {'go', 'travelling', 'locomote', 'jaunt', 'journey', 'traveling', 'trip', 'move', 'travel', 'move_around'}
# Antonyms: {'stay_in_place'}
#
# experiencing -> VBG
# Synonyms: {'feel', 'experience', 'get', 'receive', 'know', 'go_through', 'live', 'have', 'see'}
# Antonyms: None
#
#
#
#
# Sentence 6 : Innovation drives progress in science and technology.
#
#
#
#
# Sentence 7 : The laughter of children echoed through the playground.
#
# echoed -> NN
# Synonyms: {'recall', 'echo', 'ring', 'reverberate', 'resound', 'repeat'}
# Antonyms: None
#
#
#
#
# Sentence 8 : Reading books opens up a world of imagination and knowledge.
#
# Reading -> VBG
# Synonyms: {'say', 'meter_reading', 'show', 'study', 'take', 'translate', 'read', 'reading_material', 'scan', 'register', 'interpret', 'record', 'interpretation', 'Reading', 'version', 'learn', 'indication', 'recital', 'reading', 'recitation', 'understand'}
# Antonyms: None
#
# opens -> NNS
# Synonyms: {'spread', 'spread_out', 'open', 'clear', 'open_air', 'give', 'outdoors', 'out-of-doors', 'afford', 'open_up', 'unfold', 'surface'}
# Antonyms: {'close', 'fold'}
#
#
#
#
# Sentence 9 : Dancing is a form of expression that brings joy to many.
#
# is -> VBZ
# Synonyms: {'represent', 'be', 'exist', 'follow', 'cost', 'comprise', 'embody', 'personify', 'constitute', 'make_up', 'equal', 'live'}
# Antonyms: {'differ'}
#
# brings -> NNS
# Synonyms: {'play', 'institute', 'make_for', 'impart', 'convey', 'wreak', 'bring_in', 'work', 'get', 'fetch', 'add', 'contribute', 'lend', 'bring', 'bestow', 'land', 'take'}
# Antonyms: {'take_away'}
#
#
#
#
# Sentence 10 : Wildlife conservation efforts are vital to protect endangered species.
#
# are -> VBP
# Synonyms: {'represent', 'be', 'are', 'exist', 'follow', 'cost', 'comprise', 'embody', 'personify', 'constitute', 'make_up', 'equal', 'live', 'ar'}
# Antonyms: {'differ'}
#
# protect -> JJ
# Synonyms: {'protect'}
# Antonyms: None
#
#
#
#
# Sentence 11 : The sound of waves crashing on the shore is soothing to the soul.
#
# crashing -> NN
# Synonyms: {'crashing', 'dash', 'blooming', 'barge_in', 'ram', 'doss', 'fucking', 'blinking', 'flaming', 'crash', 'break_up', 'doss_down', 'break_apart', 'gate-crash', 'bally', 'go_down', 'bloody'}
# Antonyms: None
#
# is -> VBZ
# Synonyms: {'represent', 'be', 'exist', 'follow', 'cost', 'comprise', 'embody', 'personify', 'constitute', 'make_up', 'equal', 'live'}
# Antonyms: {'differ'}
#
# soothing -> VBG
# Synonyms: {'soothing', 'solace', 'comfort', 'soothe', 'console', 'assuasive'}
# Antonyms: {'irritate'}
#
#
#
#
# Sentence 12 : Exploring new cuisines can be a delightful culinary adventure.
#
# Exploring -> VBG
# Synonyms: {'explore', 'search', 'research'}
# Antonyms: None
#
# be -> VB
# Synonyms: {'represent', 'Be', 'be', 'glucinium', 'exist', 'follow', 'cost', 'comprise', 'embody', 'personify', 'constitute', 'make_up', 'equal', 'beryllium', 'live', 'atomic_number_4'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 13 : Meditation helps to calm the mind and reduce stress.
#
# helps -> VBZ
# Synonyms: {'assistance', 'serve', 'help', 'assist', 'avail', 'supporter', 'facilitate', 'helper', 'service', 'help_oneself', 'aid', 'assistant'}
# Antonyms: None
#
# calm -> VB
# Synonyms: {'lull', 'calmness', 'tranquil', 'unagitated', 'chill_out', 'serene', 'tranquillise', 'quieten', 'still', 'steady', 'equanimity', 'cool_off', 'cool_it', 'tranquillize', 'calm', 'sedate', 'tranquilize', 'quiet', 'simmer_down', 'becalm', 'settle_down', 'calm_down', 'calm_air', 'composure'}
# Antonyms: {'stimulate', 'stormy', 'discomposure', 'agitate'}
#
# reduce -> VB
# Synonyms: {'contract', 'scale_down', 'deoxidize', 'repress', 'lose_weight', 'cut', 'quash', 'subjugate', 'slim', 'keep_down', 'subdue', 'shorten', 'thin_out', 'tighten', 'deoxidise', 'foreshorten', 'dilute', 'melt_off', 'abbreviate', 'concentrate', 'slenderize', 'abridge', 'trim_back', 'trim_down', 'trim', 'come_down', 'boil_down', 'decoct', 'slim_down', 'thin', 'bring_down', 'cut_back', 'shrink', 'cut_down', 'reduce'}
# Antonyms: {'gain', 'oxidize', 'expand', 'blow_up', 'oxidise'}
#
#
#
#
# Sentence 14 : Learning from past mistakes is crucial for personal growth.
#
# Learning -> NNP
# Synonyms: {'hear', 'watch', 'ascertain', 'memorize', 'encyclopaedism', 'study', 'learnedness', 'take', 'see', 'read', 'erudition', 'scholarship', 'encyclopedism', 'memorise', 'get_word', 'get_wind', 'learning', 'learn', 'teach', 'pick_up', 'acquire', 'get_a_line', 'determine', 'eruditeness', 'check', 'con', 'discover', 'find_out', 'acquisition', 'instruct', 'larn'}
# Antonyms: None
#
# is -> VBZ
# Synonyms: {'represent', 'be', 'exist', 'follow', 'cost', 'comprise', 'embody', 'personify', 'constitute', 'make_up', 'equal', 'live'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 15 : The vibrant colors of the autumn leaves create a stunning display.
#
# leaves -> NNS
# Synonyms: {'go_out', 'allow', 'pass_on', 'exit', 'lead', 'give', 'leave_of_absence', 'folio', 'provide', 'impart', 'go_away', 'parting', 'bequeath', 'pull_up_stakes', 'leave-taking', 'go_forth', 'will', 'leave', 'foliage', 'depart', 'forget', 'leaf', 'leave_alone', 'leave_behind', 'result', 'allow_for', 'farewell', 'leafage', 'entrust', 'get_out'}
# Antonyms: {'arrive', 'enter', 'disinherit'}
#
# create -> VBP
# Synonyms: {'produce', 'make', 'create'}
# Antonyms: None
#
#
#
#
# Sentence 16 : Music festivals bring people together to celebrate and enjoy live music.
#
# bring -> VBG
# Synonyms: {'play', 'institute', 'make_for', 'impart', 'convey', 'wreak', 'bring_in', 'work', 'get', 'fetch', 'add', 'contribute', 'lend', 'bring', 'bestow', 'land', 'take'}
# Antonyms: {'take_away'}
#
# celebrate -> NN
# Synonyms: {'celebrate', 'observe', 'lionise', 'lionize', 'fete', 'keep'}
# Antonyms: None
#
# enjoy -> NN
# Synonyms: {'enjoy', 'bask', 'savour', 'relish', 'delight', 'love', 'savor', 'revel'}
# Antonyms: {'suffer'}
#
#
#
#
# Sentence 17 : Artists express themselves through various forms of creative expression.
#
# express -> NN
# Synonyms: {'expressage', 'express', 'evince', 'give_tongue_to', 'limited', 'state', 'verbalise', 'convey', 'utter', 'carry', 'press_out', 'show', 'verbalize', 'express_mail', 'extract'}
# Antonyms: {'local'}
#
#
#
#
# Sentence 18 : Cycling is an eco-friendly mode of transportation that promotes fitness.
#
# is -> VBZ
# Synonyms: {'represent', 'be', 'exist', 'follow', 'cost', 'comprise', 'embody', 'personify', 'constitute', 'make_up', 'equal', 'live'}
# Antonyms: {'differ'}
#
# promotes -> NNS
# Synonyms: {'further', 'advance', 'raise', 'encourage', 'promote', 'advertize', 'elevate', 'push', 'upgrade', 'advertise', 'kick_upstairs', 'boost'}
# Antonyms: {'demote'}
#
#
#
#
# Sentence 19 : The majestic architecture of the cathedral attracts tourists from all over the world.
#
#
#
#
# Sentence 20 : Cooking homemade meals allows for customization and healthier options.
#
# Cooking -> NN
# Synonyms: {'cookery', 'misrepresent', 'preparation', 'ready', 'make', 'wangle', 'fix', 'cook', 'cooking', 'manipulate', 'prepare', 'fudge', 'falsify', 'fake'}
# Antonyms: None
#
# allows -> NNS
# Synonyms: {'reserve', 'grant', 'allow', 'allow_for', 'appropriate', 'give_up', 'countenance', 'let', 'tolerate', 'permit', 'set_aside', 'take_into_account', 'leave', 'earmark', 'admit', 'provide'}
# Antonyms: {'forbid', 'deny', 'disallow', 'prevent'}
#
#
#
#
# Sentence 21 : Sustainable farming practices help to preserve the environment.
#
# help -> NN
# Synonyms: {'assistance', 'serve', 'help', 'assist', 'avail', 'supporter', 'facilitate', 'helper', 'service', 'help_oneself', 'aid', 'assistant'}
# Antonyms: None
#
# preserve -> VB
# Synonyms: {'save', 'keep', 'conserves', 'preserve', 'maintain', 'conserve', 'keep_up', 'uphold', 'bear_on', 'continue', 'preserves', 'carry_on'}
# Antonyms: {'discontinue'}
#
#
#
#
# Sentence 22 : Photography captures moments that last a lifetime.
#
# captures -> NNS
# Synonyms: {'appropriate', 'beguile', 'enamor', 'get', 'charm', 'seize', 'bewitch', 'entrance', 'gaining_control', 'conquer', 'capture', 'captivate', 'becharm', 'catch', 'trance', 'enchant', 'seizure', 'fascinate', 'enamour'}
# Antonyms: None
#
#
#
#
# Sentence 23 : Hiking in the mountains offers breathtaking views and a sense of accomplishment.
#
# Hiking -> VBG
# Synonyms: {'hike', 'tramp', 'hiking', 'hike_up', 'boost'}
# Antonyms: None
#
# breathtaking -> NN
# Synonyms: {'breathtaking', 'breathless'}
# Antonyms: None
#
#
#
#
# Sentence 24 : Social media platforms connect people from different parts of the world.
#
# connect -> NN
# Synonyms: {'tie', 'relate', 'get_in_touch', 'colligate', 'link_up', 'unite', 'plug_in', 'associate', 'link', 'join', 'plug_into', 'tie_in', 'touch_base', 'connect'}
# Antonyms: {'dissociate', 'unplug', 'disconnect'}
#
#
#
#
# Sentence 25 : Attending live theater performances is a cultural experience worth cherishing.
#
# Attending -> NN
# Synonyms: {'hang', 'attend', 'assist', 'pay_heed', 'take_care', 'look', 'attention', 'go_to', 'advert', 'wait_on', 'attendance', 'attend_to', 'give_ear', 'attending', 'serve', 'see'}
# Antonyms: {'nonattendance', 'inattention', 'miss'}
#
# is -> VBZ
# Synonyms: {'represent', 'be', 'exist', 'follow', 'cost', 'comprise', 'embody', 'personify', 'constitute', 'make_up', 'equal', 'live'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 26 : The beauty of nature inspires artists and poets alike.
#
#
#
#
# Sentence 27 : Journaling is a reflective practice that can enhance self-awareness.
#
# is -> VBZ
# Synonyms: {'represent', 'be', 'exist', 'follow', 'cost', 'comprise', 'embody', 'personify', 'constitute', 'make_up', 'equal', 'live'}
# Antonyms: {'differ'}
#
# enhance -> NN
# Synonyms: {'heighten', 'raise', 'enhance'}
# Antonyms: None
#
#
#
#
# Sentence 28 : Adventure travel provides thrilling experiences and unforgettable memories.
#
# provides -> VBZ
# Synonyms: {'allow', 'allow_for', 'furnish', 'render', 'supply', 'ply', 'put_up', 'offer', 'cater', 'leave', 'bring_home_the_bacon', 'provide'}
# Antonyms: None
#
#
#
#
# Sentence 29 : Inclusivity and diversity enrich communities and foster understanding.
#
#
#
#
# Sentence 30 : The importance of family bonds cannot be overstated.
#
# be -> VB
# Synonyms: {'represent', 'Be', 'be', 'glucinium', 'exist', 'follow', 'cost', 'comprise', 'embody', 'personify', 'constitute', 'make_up', 'equal', 'beryllium', 'live', 'atomic_number_4'}
# Antonyms: {'differ'}
#
# overstated -> VBN
# Synonyms: {'amplify', 'overstate', 'exaggerate', 'overdraw', 'magnify', 'hyperbolise', 'overdone', 'exaggerated', 'overstated', 'hyperbolize'}
# Antonyms: {'understate'}
#
#
#
#
# Sentence 31 : Learning new skills keeps the mind sharp and opens doors to opportunities.
#
# Learning -> VBG
# Synonyms: {'hear', 'watch', 'ascertain', 'memorize', 'encyclopaedism', 'study', 'learnedness', 'take', 'see', 'read', 'erudition', 'scholarship', 'encyclopedism', 'memorise', 'get_word', 'get_wind', 'learning', 'learn', 'teach', 'pick_up', 'acquire', 'get_a_line', 'determine', 'eruditeness', 'check', 'con', 'discover', 'find_out', 'acquisition', 'instruct', 'larn'}
# Antonyms: None
#
# keeps -> NNS
# Synonyms: {'living', 'hold', 'livelihood', 'celebrate', 'proceed', 'retain', 'go_along', 'observe', 'go_on', 'hold_open', 'keep_on', 'preserve', 'donjon', 'keep_open', 'support', 'maintain', 'hold_on', 'keep', 'restrain', 'stay_fresh', 'hold_back', 'bread_and_butter', 'save', 'prevent', 'keep_back', 'dungeon', 'sustenance', 'continue', 'sustain'}
# Antonyms: {'discontinue', 'lose', 'break', 'let'}
#
# opens -> NNS
# Synonyms: {'spread', 'spread_out', 'open', 'clear', 'open_air', 'give', 'outdoors', 'out-of-doors', 'afford', 'open_up', 'unfold', 'surface'}
# Antonyms: {'close', 'fold'}
#
#
#
#
# Sentence 32 : Entrepreneurship drives economic growth and innovation.
#
# drives -> NNS
# Synonyms: {'crusade', 'driving_force', 'motor', 'get', 'aim', 'labor', 'drive', 'take', 'repel', 'thrust', 'driving', 'push', 'ram', 'parkway', 'push_back', 'beat_back', 'effort', 'repulse', 'private_road', 'campaign', 'ride', 'labour', 'cause', 'force', 'driveway', 'force_back', 'tug', 'movement'}
# Antonyms: {'attract'}
